# %%
import uproot
import numpy as np

#read a ROOT file and extract a tree
file = uproot.open("gen_10000.root")
tree = file["Events"]

tree.show()  # Display the structure of the tree
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# EventAuxiliary       | edm::EventAuxiliary      | AsObjects(Model_edm_3a3a_Ev...
# EventProductProve... | std::vector<edm::Stor... | AsJagged(AsStridedObjects(M...
# EventSelections      | std::vector<edm::Hash... | AsObjects(AsVector(True, Mo...
# BranchListIndexes    | std::vector<uint16_t>    | AsJagged(AsDtype('>u2'), he...
# LHEEventProduct_s... | edm::Wrapper<LHEEvent... | AsGroup(<TBranchElement 'LH...
# LHEEventProduct_s... | LHEEventProduct          | AsGroup(<TBranchElement 'LH...
# LHEEventProduct_s... | int32_t                  | AsDtype('>i4')
# LHEEventProduct_s... | int32_t                  | AsDtype('>i4')
# LHEEventProduct_s... | double                   | AsDtype('>f8')
# LHEEventProduct_s... | double                   | AsDtype('>f8')
# LHEEventProduct_s... | double                   | AsDtype('>f8')
# ...

# %%
file2 = uproot.open("gen_100000_inLHE.root")
tree2 = file2["Events"]
tree2.show()  # Display the structure of the tree
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 file2 = uproot.open("gen_100000_inLHE.root")
#       2 tree2 = file2["Events"]
#       3 tree2.show()  # Display the structure of the tree
#
# File /opt/anaconda3/envs/my_cern/lib/python3.13/site-packages/uproot/reading.py:142, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     133 if not isinstance(file_path, str) and not (
#     134     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     135 ):
#     136     raise ValueError(
#     137         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     138         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     139         f"not {path!r}"
#     140     )
# --> 142 file = ReadOnlyFile(
#     143     file_path,
# ...
